# %%
import sys
sys.path.append("../")
import numpy as np
import pandas as pd
from utils import settings
from utils.visualizations import plot_eeg_windows
from utils.files import load_csv_numpy

# %% [markdown]
# <h3> CHB-MIT EEG WINDOW </h3>

# %%
###############################################
channels_list = settings["chb-mit"]["bipolar_channels"]
input_dir = settings["chb-mit"]["windows_dir"]
filename = f"{input_dir}train/chb01_03_None_ictal.csv"
eeg_array = load_csv_numpy(filename, len(channels_list))[0, :, :]
#################################################

plot_eeg_windows(eeg_array, channels_list, 256, "Figure0.png")

# %% [markdown]
# <h3> SIENA EEG WINDOW </h3>

# %%
###############################################
channels_list = settings["siena"]["bipolar_channels"]
input_dir = settings["siena"]["windows_dir"]
filename = f"{input_dir}train/PN00-1_IAS-T_ictal.csv"
eeg_array = load_csv_numpy(filename, len(channels_list))[0, :, :]
#################################################
plot_eeg_windows(eeg_array, channels_list, 512, "Figure0.png")

# %% [markdown]
# <h3> TUSZ EEG WINDOW </h3>

# %%
###############################################
channels_list = settings["tusz"]["bipolar_channels"]
input_dir = settings["tusz"]["windows_dir"]
filename = f"{input_dir}train/258_s002_t002_tcsz_noictal.csv"
eeg_array = load_csv_numpy(filename, len(channels_list))[1, :, :]
#################################################
plot_eeg_windows(eeg_array, channels_list, 400, "Figure0.png")
